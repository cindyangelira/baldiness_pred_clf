# %% [markdown]
# # Random Forest Regressor: Case Study of Baldness Prediction

# %%
import os
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings

# %%
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data/for_model.csv")

# %%
df.head()
# Out:
#    umur jenis_kelamin          gaji  is_menikah  is_keturunan      berat  \
# 0    27     Perempuan  7.957453e+06           1             0  54.315053
# 1    53     Perempuan  7.633003e+06           1             0  72.873404
# 2    37     Perempuan  6.637625e+06           1             0  46.321533
# 3    36     Perempuan  3.624871e+06           1             0  51.539781
# 4    38     Laki-laki  6.031808e+06           1             0  60.726909
#
#        tinggi     sampo  is_merokok  stress  botak_prob
# 0  170.428542   Pantone           1     5.0    0.605974
# 1  165.530097   Pantone           0     7.0    0.532860
# 2  154.599388  Moonsilk           0     4.0    0.418442
# 3  167.340481  Deadbuoy           1     9.0    0.804050
# 4  165.514773   Merpati           1     1.0    0.368371

# %%
sns.pairplot(df, diag_kind='kde')

# %%
num_cols = ['umur', 'gaji', 'berat', 'tinggi', 'stress']
cat_cols = ['jenis_kelamin']
least_frequent = df[cat_cols].apply(lambda x: x.value_counts().idxmin())

# %%
least_frequent

# %%
num_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

cat_pipeline = Pipeline([
    ('encoder', OneHotEncoder(drop='first'))
])
